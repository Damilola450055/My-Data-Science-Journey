# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('real_estate_price_size.csv')
df
# Out:
#        size       price
# 0    643.09  234314.144
# 1    656.22  228581.528
# 2    487.29  281626.336
# 3   1504.75  401255.608
# 4   1275.46  458674.256
# ..      ...         ...
# 95   549.80  252460.400
# 96  1037.44  310522.592
# 97  1504.75  383635.568
# 98   648.29  225145.248
# 99   705.29  274922.856
#
# [100 rows x 2 columns]

# %%
df.shape
# Out:
# (100, 2)

# %% [markdown]
# ##### Visualize the relationsip

# %%
plt.figure(figsize=(8,4))
plt.scatter(x='size', y='price', data=df)
plt.xlabel('size')
plt.ylabel('price')
plt.title('the relationsip between the size and the price')
plt.show()

# %%
d1 = df.head()
d1
# Out:
#       size       price
# 0   643.09  234314.144
# 1   656.22  228581.528
# 2   487.29  281626.336
# 3  1504.75  401255.608
# 4  1275.46  458674.256

# %%
plt.figure(figsize=(8,4))
plt.scatter(x='size', y='price', data=d1)
plt.xlabel('size')
plt.ylabel('price')
plt.title('the relationsip between the size and the price')
plt.show()

# %% [markdown]
# ##### formular for linear line y=mx+c5

# %%
# we split into features and target variable
x = df.iloc[:, :-1].values
y = df.iloc[:, 1].values

# %%
# !pip install scikit-learn

# %%
#fiiting in the best line
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
# %%time
model.fit(x, y)
# Out:
# CPU times: total: 0 ns
# Wall time: 4.53 ms
# LinearRegression()

# %% [markdown]
# ##### Prediction

# %%
prection = model.predict(x)
prection
# Out:
# array([245436.6193764 , 248366.95626666, 210665.37128016, 437740.81472046,
#        386568.16083095, 230282.78275422, 229323.11416106, 240466.42877881,
#        254178.53072383, 256914.70210804, 338562.41329885, 513121.66681922,
#        256914.70210804, 327155.74776484, 392259.21876711, 409836.77653386,
#        256026.45071251, 241162.74645571, 253912.94802014, 331286.78629026,
#        240441.87911713, 224591.72481806, 371389.77454709, 217603.99838742,
#        219262.2164449 , 348145.70850586, 229323.11416106, 399655.36229669,
#        253912.94802014, 435868.3450701 , 327396.78080684, 253912.94802014,
#        235351.17199854, 219262.2164449 , 293297.30072581, 240946.26307539,
#        285635.57449254, 229180.2797658 , 254897.16627498, 257756.08596762,
#        329990.11779579, 254178.53072383, 285635.57449254, 399655.36229669,
#        338562.41329885, 257756.08596762, 243227.14982471, 257756.08596762,
# ...

# %%
prection[1]
# Out:
# 248366.95626666234

# %%
y[1]
# Out:
# 228581.528

# %%
plt.figure(figsize=(8,4))
plt.scatter(x='size', y='price', data=df)
plt.plot(x, prection, color='red')
plt.xlabel('size')
plt.ylabel('price')
plt.title('the relationsip between the size and the price')
plt.show()

# %%
c = model.intercept_ 
c
# Out:
# 101912.601801229

# %%
m = model.coef_
m
# Out:
# array([223.17874259])

# %%
x = 643.09 # size
# y-mx+c
Predicted_price = m*x+c
Predicted_price
# Out:
# array([245436.6193764])

# %%
df['price'][0]
# Out:
# 234314.144
