# %% [markdown]
# # Libraries
#
# ![Top-10-Python-Libraries-3](https://github.com/user-attachments/assets/37bac531-a84c-4c78-9956-43bafb4646f9)
#
# Libraries in the context of programming and data science are collections of pre-written code that developers can use to optimize tasks and streamline the development process. They encapsulate common functions and utilities to handle specific tasks, such as:
# - **Data Manipulation**: Performing operations on data structures (e.g., pandas).
# - **Numerical Computation**: Handling mathematical operations and numerical data (e.g., NumPy, SciPy).
# - **Machine Learning**: Building and training machine learning models (e.g., Scikit-learn, TensorFlow, PyTorch).
# - **Data Visualization**: Creating graphs and plots to visualize data (e.g., Matplotlib, Seaborn, Plotly).
# - **Natural Language Processing**: Working with text data for tasks like tokenization, parsing, and sentiment analysis (e.g., NLTK, spaCy).
# - **Web Scraping**: Extracting data from web pages (e.g., BeautifulSoup, Scrapy).

# %% [markdown]
# # Working with Pandas
# ![download](https://github.com/user-attachments/assets/5f58b2a1-3bdd-41b9-ba7c-bc46a818d24b)
#
# Pandas is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series.
#
# #### Key Features of Pandas
# 1. Data Structures:
#
#     - Series: A one-dimensional labeled array capable of holding any data type.
#     - DataFrame: A two-dimensional labeled data structure with columns of potentially different types.
# 2. Data Handling:
#
#     - Importing and exporting data from various file formats (CSV, Excel, SQL databases, etc.).
#     - Handling missing data (NaN).
#     - Label-based slicing, indexing, and subsetting of large datasets.
#     - Grouping data and performing aggregate operations.

# %%
# install pandas
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas

# %% [markdown]
# ## Series

# %%
data = [10, 20, 30, 40, 50]

# %%
x = pandas.Series(data)

# %%
x
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# alias of pandas
import pandas as pd

# %%
country = ['Nigeria', 'Ghana', 'South Africa']
country = pd.Series(country)

# %%
country
# Out:
# 0         Nigeria
# 1           Ghana
# 2    South Africa
# dtype: object

# %%
# custom index
marks = [67, 58, 93, 75]
subjects = ['Maths', 'English', 'Science', 'Hindi']

mark_series = pd.Series(marks, index=subjects)

# %%
mark_series
# Out:
# Maths      67
# English    58
# Science    93
# Hindi      75
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
# create a dataframe from a dictionary
data = {
    'Name': ['Alice', 'Barnabas', 'Catherine', 'Dorris'],
    'Age': [28, 29, 35, 26],
    'City': ['New York', 'Los Angeles', 'Cairo', 'Paris']
}

# %%
data
# Out:
# {'Name': ['Alice', 'Barnabas', 'Catherine', 'Dorris'],
#  'Age': [28, 29, 35, 26],
#  'City': ['New York', 'Los Angeles', 'Cairo', 'Paris']}

# %%
df = pd.DataFrame(data)
df
# Out:
#         Name  Age         City
# 0      Alice   28     New York
# 1   Barnabas   29  Los Angeles
# 2  Catherine   35        Cairo
# 3     Dorris   26        Paris

# %%
# Add a new column -- Gender
df['Gender'] = ['Female', 'Male', 'Female', 'Male']

# %%
df
# Out:
#         Name  Age         City  Gender
# 0      Alice   28     New York  Female
# 1   Barnabas   29  Los Angeles    Male
# 2  Catherine   35        Cairo  Female
# 3     Dorris   26        Paris    Male

# %% [markdown]
# ## Data Handling
#
# #### Import data in pandas
# Data are in different formats, such as:
# - CSV
# - TSV
# - JSON
# - SQL

# %%
# reading a csv file into a dataframe
df = pd.read_csv('locations.csv')

# %%
df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# 4                           NaN        5819.495
# ..                          ...             ...
# 207                       0.700        1479.147
# 208                       2.000        3689.251
# 209                       1.700        1899.775
# 210                       2.705       15469.207
# 211                         NaN             NaN
#
# [212 rows x 6 columns]

# %%
# specify path -- "C:\Users\User\Documents\Python\Web Scraping on IMDB Movie\imdb_top_250_movies.csv"

# %%
movie_df = pd.read_csv("C:/Users/User/Documents/Python/Web Scraping on IMDB Movie/imdb_top_250_movies.csv")

# %%
movie_df
# Out:
#                         Title  Release Date  Ratings  Ranking Runtime  \
# 0    The Shawshank Redemption          1994      9.3        1  2h 22m
# 1               The Godfather          1972      9.2        2  2h 55m
# 2             The Dark Knight          2008      9.0        3  2h 32m
# 3       The Godfather Part II          1974      9.0        4  3h 22m
# 4                12 Angry Men          1957      9.0        5  1h 36m
# ..                        ...           ...      ...      ...     ...
# 245     It Happened One Night          1934      8.1      246  1h 45m
# 246                   Aladdin          1992      8.0      247  1h 30m
# 247                  Drishyam          2015      8.2      248  2h 43m
# 248        Dances with Wolves          1990      8.0      249   3h 1m
# 249                 Andhadhun          2018      8.2      250  2h 19m
#
#     Popularity
# 0         2.9M
# 1           2M
# 2         2.9M
# 3         1.4M
# 4         867K
# ..         ...
# 245       112K
# 246       468K
# 247        95K
# 248       291K
# 249       103K
#
# [250 rows x 6 columns]

# %% [markdown]
# #### Get your file from the URL

# %%
url = "https://raw.githubusercontent.com/Oyeniran20/Machine-Learning/main/6.%20Trees/housing.csv"

# %%
url
# Out:
# 'https://raw.githubusercontent.com/Oyeniran20/Machine-Learning/main/6.%20Trees/housing.csv'

# %%
data = pd.read_csv(url)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %% [markdown]
# #### Sep Parameter

# %%
col_name = ['sn', 'title', 'release_year', 'ratings', 'vote_count', 'genre']
df = pd.read_csv('movie_titles_metadata.tsv', sep='\t', names=col_name)
df
# Out:
#        sn                       title release_year  ratings  vote_count  \
# 0      m0  10 things i hate about you         1999      6.9     62847.0
# 1      m1  1492: conquest of paradise         1992      6.2     10421.0
# 2      m2                  15 minutes         2001      6.1     25854.0
# 3      m3       2001: a space odyssey         1968      8.4    163227.0
# 4      m4                     48 hrs.         1982      6.9     22289.0
# ..    ...                         ...          ...      ...         ...
# 612  m612                    watchmen         2009      7.8    135229.0
# 613  m613                         xxx         2002      5.6     53505.0
# 614  m614                       x-men         2000      7.4    122149.0
# 615  m615          young frankenstein         1974      8.0     57618.0
# 616  m616                   zulu dawn         1979      6.4      1911.0
#
#                                                  genre
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# 2                ['action' 'crime' 'drama' 'thriller']
# 3                     ['adventure' 'mystery' 'sci-fi']
# 4       ['action' 'comedy' 'crime' 'drama' 'thriller']
# ..                                                 ...
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']
#
# [617 rows x 6 columns]

# %%
df1 = pd.read_csv('test.csv', header=1)

# %%
pd.read_excel('exchange_rate.xlsx')
# Out:
#     Unnamed: 0                          provider  \
# 0          INR  https://www.exchangerate-api.com
# 1          AED  https://www.exchangerate-api.com
# 2          AFN  https://www.exchangerate-api.com
# 3          ALL  https://www.exchangerate-api.com
# 4          AMD  https://www.exchangerate-api.com
# ..         ...                               ...
# 157        XPF  https://www.exchangerate-api.com
# 158        YER  https://www.exchangerate-api.com
# 159        ZAR  https://www.exchangerate-api.com
# 160        ZMW  https://www.exchangerate-api.com
# 161        ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# 0    https://www.exchangerate-api.com/docs/free
# 1    https://www.exchangerate-api.com/docs/free
# 2    https://www.exchangerate-api.com/docs/free
# 3    https://www.exchangerate-api.com/docs/free
# 4    https://www.exchangerate-api.com/docs/free
# ..                                          ...
# 157  https://www.exchangerate-api.com/docs/free
# 158  https://www.exchangerate-api.com/docs/free
# 159  https://www.exchangerate-api.com/docs/free
# 160  https://www.exchangerate-api.com/docs/free
# 161  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# 0    https://www.exchangerate-api.com/terms  INR 2024-12-06
# 1    https://www.exchangerate-api.com/terms  INR 2024-12-06
# 2    https://www.exchangerate-api.com/terms  INR 2024-12-06
# 3    https://www.exchangerate-api.com/terms  INR 2024-12-06
# 4    https://www.exchangerate-api.com/terms  INR 2024-12-06
# ..                                      ...  ...        ...
# 157  https://www.exchangerate-api.com/terms  INR 2024-12-06
# 158  https://www.exchangerate-api.com/terms  INR 2024-12-06
# 159  https://www.exchangerate-api.com/terms  INR 2024-12-06
# 160  https://www.exchangerate-api.com/terms  INR 2024-12-06
# 161  https://www.exchangerate-api.com/terms  INR 2024-12-06
#
#      time_last_updated   rates
# 0           1733443201  1.0000
# 1           1733443201  0.0433
# 2           1733443201  0.8080
# 3           1733443201  1.1000
# 4           1733443201  4.7500
# ..                 ...     ...
# 157         1733443201  1.3400
# 158         1733443201  2.9500
# 159         1733443201  0.2130
# 160         1733443201  0.3200
# 161         1733443201  0.3020
#
# [162 rows x 8 columns]

# %%
pd.read_json('train.json')
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# ### Important Functions and Attributes

# %%
# preview the first 5 rows
df.head()
# Out:
#    sn                       title release_year  ratings  vote_count  \
# 0  m0  10 things i hate about you         1999      6.9     62847.0
# 1  m1  1492: conquest of paradise         1992      6.2     10421.0
# 2  m2                  15 minutes         2001      6.1     25854.0
# 3  m3       2001: a space odyssey         1968      8.4    163227.0
# 4  m4                     48 hrs.         1982      6.9     22289.0
#
#                                             genre
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
# last 5 rows
df.tail()
# Out:
#        sn               title release_year  ratings  vote_count  \
# 612  m612            watchmen         2009      7.8    135229.0
# 613  m613                 xxx         2002      5.6     53505.0
# 614  m614               x-men         2000      7.4    122149.0
# 615  m615  young frankenstein         1974      8.0     57618.0
# 616  m616           zulu dawn         1979      6.4      1911.0
#
#                                                  genre
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']

# %%
df.sample(5)
# Out:
#        sn               title release_year  ratings  vote_count  \
# 186  m186        smokin' aces         2006      6.6     58048.0
# 326  m326  do the right thing         1989      7.9     27164.0
# 483  m483              maniac         1980      6.2      3382.0
# 549  m549      the terminator         1984      8.1    183538.0
# 105  m105        jackie brown         1997      7.6     85496.0
#
#                                      genre
# 186  ['action' 'crime' 'drama' 'thriller']
# 326                              ['drama']
# 483          ['drama' 'horror' 'thriller']
# 549         ['action' 'sci-fi' 'thriller']
# 105           ['crime' 'drama' 'thriller']

# %%
df.shape
# Out:
# (617, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sn            617 non-null    object
#  1   title         616 non-null    object
#  2   release_year  616 non-null    object
#  3   ratings       616 non-null    float64
#  4   vote_count    616 non-null    float64
#  5   genre         616 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.1+ KB

# %%
# summary statistics
df.describe()
# Out:
#           ratings     vote_count
# count  616.000000     616.000000
# mean     6.865584   49901.698052
# std      1.215463   61898.367352
# min      2.500000       9.000000
# 25%      6.200000    9992.500000
# 50%      7.000000   27121.500000
# 75%      7.800000   66890.000000
# max      9.300000  419312.000000

# %%
# missing Value
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# sn              0
# title           1
# release_year    1
# ratings         1
# vote_count      1
# genre           1
# dtype: int64

# %%
import numpy as np

# %%
# Sample DataFrame with missing values
data = {
    'A': [1, 2, 3, 4], 
    'B': [5, np.nan, np.nan, 8], 
    'C': [10, 11, 12, np.nan]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#    A    B     C
# 0  1  5.0  10.0
# 1  2  NaN  11.0
# 2  3  NaN  12.0
# 3  4  8.0   NaN

# %%
df.isna().sum()
# Out:
# A    0
# B    2
# C    1
# dtype: int64
