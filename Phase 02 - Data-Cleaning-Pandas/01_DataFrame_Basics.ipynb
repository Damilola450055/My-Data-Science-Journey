# %% [markdown]
# ## Pandas

# %%
# pandas is used for data structure and data manimuplation
# Data structure is majorly 2 forms
# 1. series is a 1 dimensional lable 
# 2. data frame is 2 dimensional label.

import pandas

# %%
# SERIES
data = [10, 20, 30, 40, 50]

# %%
x = pandas.Series(data)
x
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# alias of pandas
import pandas as pd

# %%
country = [ 'nigeria', 'ghana', 'south africa']
country = pd.Series(country)
country
# Out:
# 0         nigeria
# 1           ghana
# 2    south africa
# dtype: object

# %%
# customize index
marks = [67, 58, 93, 75]
subject = ['math', 'english', 'science', 'hindi']

mark_series = pd.Series(marks, index=subject)
mark_series
# Out:
# math       67
# english    58
# science    93
# hindi      75
# dtype: int64

# %%
# DATAFRAME
# creating a datafram from dictionary
data = {
    'name': ['paul', 'john', 'peter', 'doris'],
    'age': [28, 29, 35, 26],
    'city': ['new jersey', 'los angeles', 'florida', 'new york']
    
}
data
# Out:
# {'name': ['paul', 'john', 'peter', 'doris'],
#  'age': [28, 29, 35, 26],
#  'city': ['new jersey', 'los angeles', 'florida', 'new york']}

# %%
df = pd.DataFrame(data)
df
# Out:
#     name  age         city
# 0   paul   28   new jersey
# 1   john   29  los angeles
# 2  peter   35      florida
# 3  doris   26     new york

# %%
# add a new column -- gender
df['gender'] = ['male', 'male', 'male', 'female']
df
# Out:
#     name  age         city  gender
# 0   paul   28   new jersey    male
# 1   john   29  los angeles    male
# 2  peter   35      florida    male
# 3  doris   26     new york  female

# %%
# DATA HANDLING 
# We can import data in pandas
# data are in different format
#- CSV
#- TSV
#- JSON
#- SQL

# %%
# reading a csv file to dataframe
df = pd.read_csv('locations.csv')
df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
# Reading data from URL
url = "https://raw.githubusercontent.com/Oyeniran20/Machine-Learning/main/6.%20Trees/housing.csv"
url
# Out:
# 'https://raw.githubusercontent.com/Oyeniran20/Machine-Learning/main/6.%20Trees/housing.csv'

# %%
data = pd.read_csv(url)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# reading TSV file with read_csv
df = pd.read_csv('movie_titles_metadata.tsv')
df
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
# using sep to clean the TSV open with Read_csv
col_name = ['sn', 'title', 'release_year', 'ratings', 'vote_count', 'genre']
df = pd.read_csv('movie_titles_metadata.tsv', sep='\t', names=col_name)
df
# Out:
#        sn                       title release_year  ratings  vote_count  \
# 0      m0  10 things i hate about you         1999      6.9     62847.0
# 1      m1  1492: conquest of paradise         1992      6.2     10421.0
# 2      m2                  15 minutes         2001      6.1     25854.0
# 3      m3       2001: a space odyssey         1968      8.4    163227.0
# 4      m4                     48 hrs.         1982      6.9     22289.0
# ..    ...                         ...          ...      ...         ...
# 612  m612                    watchmen         2009      7.8    135229.0
# 613  m613                         xxx         2002      5.6     53505.0
# 614  m614                       x-men         2000      7.4    122149.0
# 615  m615          young frankenstein         1974      8.0     57618.0
# 616  m616                   zulu dawn         1979      6.4      1911.0
#
#                                                  genre
# ...

# %%
pd.read_csv('test.csv')
# Out:
#    Unnamed: 0   Unnamed: 1 Unnamed: 2              Unnamed: 3 Unnamed: 4  \
# 0           0  enrollee_id       city  city_development_index     gender
# 1           1        29725    city_40                   0.776       Male
# 2           2        11561    city_21                   0.624        NaN
# 3           3        33241   city_115                   0.789        NaN
# 4           4          666   city_162                   0.767       Male
#
#                 Unnamed: 5           Unnamed: 6       Unnamed: 7  \
# 0      relevent_experience  enrolled_university  education_level
# 1   No relevent experience        no_enrollment         Graduate
# 2   No relevent experience     Full time course         Graduate
# 3   No relevent experience                  NaN         Graduate
# 4  Has relevent experience        no_enrollment          Masters
#
#          Unnamed: 8  Unnamed: 9   Unnamed: 10     Unnamed: 11   Unnamed: 12  \
# ...

# %%
# using header parameter
pd.read_csv('test.csv', header=1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %%
# important function and attributes

# %%
# preview the first 5 rows
df.head()
# Out:
#    sn                       title release_year  ratings  vote_count  \
# 0  m0  10 things i hate about you         1999      6.9     62847.0
# 1  m1  1492: conquest of paradise         1992      6.2     10421.0
# 2  m2                  15 minutes         2001      6.1     25854.0
# 3  m3       2001: a space odyssey         1968      8.4    163227.0
# 4  m4                     48 hrs.         1982      6.9     22289.0
#
#                                             genre
# 0                            ['comedy' 'romance']
# 1     ['adventure' 'biography' 'drama' 'history']
# 2           ['action' 'crime' 'drama' 'thriller']
# 3                ['adventure' 'mystery' 'sci-fi']
# 4  ['action' 'comedy' 'crime' 'drama' 'thriller']

# %%
# preview the last 5 rows
df.tail()
# Out:
#        sn               title release_year  ratings  vote_count  \
# 612  m612            watchmen         2009      7.8    135229.0
# 613  m613                 xxx         2002      5.6     53505.0
# 614  m614               x-men         2000      7.4    122149.0
# 615  m615  young frankenstein         1974      8.0     57618.0
# 616  m616           zulu dawn         1979      6.4      1911.0
#
#                                                  genre
# 612  ['action' 'crime' 'fantasy' 'mystery' 'sci-fi'...
# 613                     ['action' 'adventure' 'crime']
# 614                                ['action' 'sci-fi']
# 615                                ['comedy' 'sci-fi']
# 616     ['action' 'adventure' 'drama' 'history' 'war']

# %%
# preview random rows
df.sample(5)
# Out:
#        sn              title release_year  ratings  vote_count  \
# 5      m5  the fifth element         1997      7.5    133756.0
# 15    m15             aliens         1986      8.5    173518.0
# 379  m379          halloween         1978      7.9     64690.0
# 68    m68       galaxy quest         1999      7.2     53004.0
# 591  m591         unforgiven         1992      8.3    101270.0
#
#                                                  genre
# 5    ['action' 'adventure' 'romance' 'sci-fi' 'thri...
# 15                      ['action' 'sci-fi' 'thriller']
# 379                              ['horror' 'thriller']
# 68            ['action' 'adventure' 'comedy' 'sci-fi']
# 591                                ['drama' 'western']

# %%
# counting number of rows
df.shape
# Out:
# (617, 6)

# %%
# checking information of  a data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sn            617 non-null    object
#  1   title         616 non-null    object
#  2   release_year  616 non-null    object
#  3   ratings       616 non-null    float64
#  4   vote_count    616 non-null    float64
#  5   genre         616 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 29.1+ KB

# %%
# summary stats
df.describe() #.describe() work for only numeric part by default
# Out:
#           ratings     vote_count
# count  616.000000     616.000000
# mean     6.865584   49901.698052
# std      1.215463   61898.367352
# min      2.500000       9.000000
# 25%      6.200000    9992.500000
# 50%      7.000000   27121.500000
# 75%      7.800000   66890.000000
# max      9.300000  419312.000000

# %%
# summary stats
df.describe(include='all') # but we can use the include='all' to to view all summary
# Out:
#          sn                       title release_year     ratings  \
# count   617                         616          616  616.000000
# unique  617                         616           88         NaN
# top      m0  10 things i hate about you         1999         NaN
# freq      1                           1           42         NaN
# mean    NaN                         NaN          NaN    6.865584
# std     NaN                         NaN          NaN    1.215463
# min     NaN                         NaN          NaN    2.500000
# 25%     NaN                         NaN          NaN    6.200000
# 50%     NaN                         NaN          NaN    7.000000
# 75%     NaN                         NaN          NaN    7.800000
# max     NaN                         NaN          NaN    9.300000
#
#            vote_count      genre
# count      616.000000        616
# unique            NaN        289
# top               NaN  ['drama']
# freq              NaN         34
# ...

# %%
# finding and counting missing value
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.isna().sum()
# Out:
# sn              0
# title           1
# release_year    1
# ratings         1
# vote_count      1
# genre           1
# dtype: int64

# %%
# Sample DataFrame with missing values
import numpy as np
data = {
    'A': [1, 2, 3, 4], 
    'B': [5, np.nan, np.nan, 8], 
    'C': [10, 11, 12, np.nan]
}
df = pd.DataFrame(data)
df
# Out:
#    A    B     C
# 0  1  5.0  10.0
# 1  2  NaN  11.0
# 2  3  NaN  12.0
# 3  4  8.0   NaN

# %%
df.isna().sum()
# Out:
# A    0
# B    2
# C    1
# dtype: int64

# %% [markdown]
# #### Continuation on Panda

# %%
# Dealing with missing values
# we fill the missing value with 0, mean, median, mode
# we drop missing value
# forward or backward fill

# %%
# Droping missing value
x = df.dropna() # Axis 0 = rows Axis 1 = columns
x
# Out:
#    A    B     C
# 0  1  5.0  10.0

# %%
y = df.dropna(axis = 1)
y
# Out:
#    A
# 0  1
# 1  2
# 2  3
# 3  4

# %%
# filling the missing value with 0

# %%
z = df.fillna(0)
z
# Out:
#    A    B     C
# 0  1  5.0  10.0
# 1  2  0.0  11.0
# 2  3  0.0  12.0
# 3  4  8.0   0.0

# %%
# filling the missin value with mean
p = df.fillna(df.mean())
p
# Out:
#    A    B     C
# 0  1  5.0  10.0
# 1  2  6.5  11.0
# 2  3  6.5  12.0
# 3  4  8.0  11.0

# %%
# forward fill
fw = df.fillna(method ='ffill')
fw
# Out:
# C:\Users\olayi\AppData\Local\Temp\ipykernel_16048\1584870724.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   fw = df.fillna(method ='ffill')
#    A    B     C
# 0  1  5.0  10.0
# 1  2  5.0  11.0
# 2  3  5.0  12.0
# 3  4  8.0  12.0

# %%
bw = df.fillna(method ='bfill')
bw
# Out:
# C:\Users\olayi\AppData\Local\Temp\ipykernel_16048\3112992326.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bw = df.fillna(method ='bfill')
#    A    B     C
# 0  1  5.0  10.0
# 1  2  8.0  11.0
# 2  3  8.0  12.0
# 3  4  8.0   NaN

# %%
df.ffill()
# Out:
#    A    B     C
# 0  1  5.0  10.0
# 1  2  5.0  11.0
# 2  3  5.0  12.0
# 3  4  8.0  12.0

# %%
df.bfill()
# Out:
#    A    B     C
# 0  1  5.0  10.0
# 1  2  8.0  11.0
# 2  3  8.0  12.0
# 3  4  8.0   NaN

# %%
raw_data_1 = {
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'role': ['Python Developer', 'Python Developer', 'PHP Developer', 'C++ Developer', 'Data '],
        'experience': [3,4,4,3,2],
        'qualification': ['Graduate', 'Graduate', 'Post Graduate', 'Graduate', 'Post Graduate']
}

raw_data_2 = {
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce'], 
        'role': ['Data Analyst', 'ML Engineer', 'Data Scientist', 'Business Analyst'],
        'experience': [2, 6, 4, 7],
        'salary': ['30k', '45k', '60k', '35k'],
        'awards_collected': [0, 2, 3, 1]
}

# %%
df1 = pd.DataFrame(raw_data_1)
df2 = pd.DataFrame(raw_data_2)

# %%
df1
# Out:
#   first_name              role  experience  qualification
# 0       Alex  Python Developer           3       Graduate
# 1        Amy  Python Developer           4       Graduate
# 2      Allen     PHP Developer           4  Post Graduate
# 3      Alice     C++ Developer           3       Graduate
# 4     Ayoung             Data            2  Post Graduate

# %%
df2
# Out:
#   first_name              role  experience salary  awards_collected
# 0      Billy      Data Analyst           2    30k                 0
# 1      Brian       ML Engineer           6    45k                 2
# 2       Bran    Data Scientist           4    60k                 3
# 3      Bryce  Business Analyst           7    35k                 1

# %%
pd.concat([df1, df2], axis = 0, ignore_index = 'true')
# Out:
#   first_name              role  experience  qualification salary  \
# 0       Alex  Python Developer           3       Graduate    NaN
# 1        Amy  Python Developer           4       Graduate    NaN
# 2      Allen     PHP Developer           4  Post Graduate    NaN
# 3      Alice     C++ Developer           3       Graduate    NaN
# 4     Ayoung             Data            2  Post Graduate    NaN
# 5      Billy      Data Analyst           2            NaN    30k
# 6      Brian       ML Engineer           6            NaN    45k
# 7       Bran    Data Scientist           4            NaN    60k
# 8      Bryce  Business Analyst           7            NaN    35k
#
#    awards_collected
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# 5               0.0
# 6               2.0
# 7               3.0
# 8               1.0

# %%
pd.concat([df1, df2], axis = 1)
# Out:
#   first_name              role  experience  qualification first_name  \
# 0       Alex  Python Developer           3       Graduate      Billy
# 1        Amy  Python Developer           4       Graduate      Brian
# 2      Allen     PHP Developer           4  Post Graduate       Bran
# 3      Alice     C++ Developer           3       Graduate      Bryce
# 4     Ayoung             Data            2  Post Graduate        NaN
#
#                role  experience salary  awards_collected
# 0      Data Analyst         2.0    30k               0.0
# 1       ML Engineer         6.0    45k               2.0
# 2    Data Scientist         4.0    60k               3.0
# 3  Business Analyst         7.0    35k               1.0
# 4               NaN         NaN    NaN               NaN

# %%
raw_data_1 = {
        'id': ['A1', 'A2', 'A3', 'A4', 'A5'],
        'project_id_initial': ['DX13', 'DX11','DX29', 'DX30', 'DX28'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'role': ['Python Developer', 'Python Developer', 'PHP Developer', 'C++ Developer', 'Data '],
        'experience': [3,4,4,3,2],
        'qualification': ['Graduate', 'Graduate', 'Post Graduate', 'Graduate', 'Post Graduate']
}

raw_data_2 = {
        'id': ['A1', 'A2', 'A3', 'A6'],
        'project_id_final': ['DX13', 'DX11', 'DX30', 'DX29'],
        'salary': ['30k', '45k', '60k', '35k'],
        'awards_collected': [0, 2, 3, 1]
}

# %%
# Using merge. inner join, left outer join, right outer join, full outer join.
df1 = pd.DataFrame(raw_data_1)
df2 = pd.DataFrame(raw_data_2)

# %%
df1
# Out:
#    id project_id_initial first_name              role  experience  \
# 0  A1               DX13       Alex  Python Developer           3
# 1  A2               DX11        Amy  Python Developer           4
# 2  A3               DX29      Allen     PHP Developer           4
# 3  A4               DX30      Alice     C++ Developer           3
# 4  A5               DX28     Ayoung             Data            2
#
#    qualification
# 0       Graduate
# 1       Graduate
# 2  Post Graduate
# 3       Graduate
# 4  Post Graduate

# %%
df2
# Out:
#    id project_id_final salary  awards_collected
# 0  A1             DX13    30k                 0
# 1  A2             DX11    45k                 2
# 2  A3             DX30    60k                 3
# 3  A6             DX29    35k                 1

# %%
# inner join returns only the rows where there is a match in both tables
# left outer join  returns all records from the left table
# full outer join returns all records when there is a match in either the left or the right table.
# right outer join returns all records from the right table, and the matching records from the left table.

pd.merge(df1, df2)
# Out:
#    id project_id_initial first_name              role  experience  \
# 0  A1               DX13       Alex  Python Developer           3
# 1  A2               DX11        Amy  Python Developer           4
# 2  A3               DX29      Allen     PHP Developer           4
#
#    qualification project_id_final salary  awards_collected
# 0       Graduate             DX13    30k                 0
# 1       Graduate             DX11    45k                 2
# 2  Post Graduate             DX30    60k                 3
